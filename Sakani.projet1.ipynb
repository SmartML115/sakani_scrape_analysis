# %%
import requests
from   bs4 import BeautifulSoup
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#pip install requests
#pip install beautifulsoup4
#pip install lxml


page = requests.get("https://www.kaggle.com/datasets/majedalhulayel/sakani-projects-saudi-arabia")

def main(page):
   
    src = page.content
    print(src)
   
main(page)
# Out:
# b'\r\n\r\n<!DOCTYPE html>\r\n<html lang="en">\r\n\r\n<head>\r\n  <title>Sakani Projects | Saudi Arabia | Kaggle</title>\r\n  <meta charset="utf-8" />\r\n    <meta name="robots" content="index, follow" />\r\n  <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />\r\n  <meta name="turbolinks-cache-control" content="no-cache" />\r\n    <meta name="keywords" content="real estate,housing,middle east" />\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">\r\n  <meta name="theme-color" content="#008ABC" />\r\n  <script nonce="ZIrMdJxOe9zqJDZ/HBsg4g==" type="text/javascript">\r\n    window["pageRequestStartTime"] = 1711914990398;\r\n    window["pageRequestEndTime"] = 1711914990501;\r\n    window["initialPageLoadStartTime"] = new Date().getTime();\r\n  </script>\r\n  <script nonce="ZIrMdJxOe9zqJDZ/HBsg4g==" i
# ...

# %%
def main(page):
   
    src = page.content
    soup = BeautifulSoup(src, 'lxml')
    print(soup)
main(page)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Sakani Projects | Saudi Arabia | Kaggle</title>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="robots"/>
# <meta content="Kaggle is the world’s largest data science community with powerful tools and resources to help you achieve your data science goals." name="description"/>
# <meta content="no-cache" name="turbolinks-cache-control"/>
# <meta content="real estate,housing,middle east" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#008ABC" name="theme-color"/>
# <script nonce="ZIrMdJxOe9zqJDZ/HBsg4g==" type="text/javascript">
#     window["pageRequestStartTime"] = 1711914990398;
#     window["pageRequestEndTime"] = 1711914990501;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# ...

# %%
file_path = ('anaconda3/TSK/Sskani/archive (1).zip.csv')
csv_path = "anaconda3/TSK/Sskani/Sakani Projects.csv"


df = pd.read_csv(r"C:\Users\Ahliy\Downloads\archive (1).zip")


print(df.head())

print(df.info())

print(df.describe())

print(df.shape)

print(df['city_id'].value_counts())
# Out:
#              id  location_lat  location_lon  city_id city_name_ar  \
# 0  project_1044     24.560109     46.519438       14       الرياض
# 1  project_1033     24.793165     46.633768       14       الرياض
# 2   project_681     24.058337     42.836919     3025         عفيف
# 3   project_378     18.446355     42.098271     3274        محايل
# 4   project_386     24.545443     44.404584      716     الدوادمي
#
#   city_name_en  region_id region_key region_name_ar region_name_en  ...  \
# 0    AR RIYADH          1     riyadh         الرياض         Riyadh  ...
# 1    AR RIYADH          1     riyadh         الرياض         Riyadh  ...
# 2         AFIF          1     riyadh         الرياض         Riyadh  ...
# 3      MUHAYIL          7       asir           عسير          'Asir  ...
# 4  AD DUWADIMI          1     riyadh         الرياض         Riyadh  ...
#
#    resource_id  resource_type  subsidizable          type  \
# 0         1044       projects             1  marketplaces
# ...

# %%
df['city_name_ar'].value_counts(). plot(kind='hist', bins=200, alpha=0.9)
plt.xlabel('city_name_ar')
plt.title('Histogram of city name')
plt.show();

# %%
import seaborn as sns
sns.boxplot(x=df['city_id'], y=df['city_id'])
plt.xlabel('city_id')
plt.ylabel('city_id')
plt.title('location_lat')
plt.show()

# %%
df['city_name_en'].value_counts().plot(kind='hist', bins=200, alpha=0.9)

# Getting the unique city names
city_names = df['city_name_en'].unique()

# Specify the start and end indices of the range
start_index = 0 # Replace with your desired start index
end_index = 48  # Replace with your desired end index

# Select the range of city names and their corresponding indices
selected_city_names = city_names[start_index:end_index]
selected_indices = range(start_index, end_index)

# Set the step size for the tick positions
step = 2  # Replace with your desired step size

# Set the x-ticks and labels for the selected range with the specified step size
plt.xticks(selected_indices[::step], selected_city_names[::step], rotation=90)

# Changing the x-axis label
plt.xlabel('city_name_en')

# Adding title
plt.title('Histogram of city name')

# Displaying the plot
plt.show()

# %%
mean = df['location_lat'].mean()
median = df['location_lat'].median()
mode = df['location_lat'].mode()
std = df['location_lat'].std()
min_value = df['location_lat'].min()
max_value = df['location_lat'].max()
quartiles = df['location_lat'].quantile([0.25, 0.5, 0.75])

print('Mean:', mean)
print('Median:', median)
print('Mode:', mode)
print('Standard Deviation:', std)
print('Minimum:', min_value)
print('Maximum:', max_value)
print('Quartiles:', quartiles)
# Out:
# Mean: 22.563974833756475
# Median: 24.5587075
# Mode: 0    0.0
# Name: location_lat, dtype: float64
# Standard Deviation: 6.627172112907374
# Minimum: 0.0
# Maximum: 31.649161
# Quartiles: 0.25    21.419040
# 0.50    24.558708
# 0.75    26.304951
# Name: location_lat, dtype: float64

# %%
import pandas as pd
 
duplicates = df[df.duplicated()]

#  الصفوف المكررة
print("الصفوف المكررة:")
print(duplicates)
# Out:
# الصفوف المكررة:
# Empty DataFrame
# Columns: [id, location_lat, location_lon, city_id, city_name_ar, city_name_en, region_id, region_key, region_name_ar, region_name_en, region_order_sequence, availability, available_units_count, available_units_for_auctions_count, basement, bookable, city_order_sequence, delegated_by_broker, developer_name, driver_room, elevator, group_unit_id, maid_room, max_area, max_bathroom, max_bed_room, max_price, max_street_width, max_unit_age, min_area, min_bathroom, min_bed_room, min_price, min_street_width, min_unit_age, pool, project_name, project_type, promoted, publish, publish_date, resource_id, resource_type, subsidizable, type, under_construction_status, unit_types_0, unit_types_1, unit_types_2, use_register_interest_flag, views_count]
# Index: []
#
# [0 rows x 51 columns]

# %%
import pandas as pd
 
duplicates = df[df.duplicated()]

#  الصفوف المكررة
print("الصفوف المكررة:")
print(duplicates)
# Out:
# الصفوف المكررة:
# Empty DataFrame
# Columns: [id, location_lat, location_lon, city_id, city_name_ar, city_name_en, region_id, region_key, region_name_ar, region_name_en, region_order_sequence, availability, available_units_count, available_units_for_auctions_count, basement, bookable, city_order_sequence, delegated_by_broker, developer_name, driver_room, elevator, group_unit_id, maid_room, max_area, max_bathroom, max_bed_room, max_price, max_street_width, max_unit_age, min_area, min_bathroom, min_bed_room, min_price, min_street_width, min_unit_age, pool, project_name, project_type, promoted, publish, publish_date, resource_id, resource_type, subsidizable, type, under_construction_status, unit_types_0, unit_types_1, unit_types_2, use_register_interest_flag, views_count]
# Index: []
#
# [0 rows x 51 columns]

# %%
df.drop_duplicates(inplace=True)

# طباعة الإطار البيانات بعد معالجة البيانات المكررة
print("\nالإطار البيانات بعد معالجة البيانات المكررة:")
print(df)
# Out:
# الإطار البيانات بعد معالجة البيانات المكررة:
#                id  location_lat  location_lon  city_id     city_name_ar  \
# 0    project_1044     24.560109     46.519438       14           الرياض
# 1    project_1033     24.793165     46.633768       14           الرياض
# 2     project_681     24.058337     42.836919     3025             عفيف
# 3     project_378     18.446355     42.098271     3274            محايل
# 4     project_386     24.545443     44.404584      716         الدوادمي
# ..            ...           ...           ...      ...              ...
# 381   project_238     26.177791     43.612227       24         البكيرية
# 382   project_236     18.025902     43.152436     2798       سراة عبيدة
# 383   project_237     24.469556     39.807306       26  المدينة المنورة
# 384   project_374     18.343258     42.519739       50             ابها
# 385   project_241     26.134406     44.059930       20            عنيزة
#
# ...

# %%
import numpy as np

# تحديد الأعمدة الرقمية
numeric_columns = df.select_dtypes(include=[np.number]).columns.tolist()

# تعويض القيم المفقودة بالمتوسط في الأعمدة الرقمية فقط
df[numeric_columns] = df[numeric_columns].fillna(df[numeric_columns].mean())

# طباعة الإطار البيانات بعد معالجة القيم المفقودة
print(df)
# Out:
#                id  location_lat  location_lon  city_id     city_name_ar  \
# 0    project_1044     24.560109     46.519438       14           الرياض
# 1    project_1033     24.793165     46.633768       14           الرياض
# 2     project_681     24.058337     42.836919     3025             عفيف
# 3     project_378     18.446355     42.098271     3274            محايل
# 4     project_386     24.545443     44.404584      716         الدوادمي
# ..            ...           ...           ...      ...              ...
# 381   project_238     26.177791     43.612227       24         البكيرية
# 382   project_236     18.025902     43.152436     2798       سراة عبيدة
# 383   project_237     24.469556     39.807306       26  المدينة المنورة
# 384   project_374     18.343258     42.519739       50             ابها
# 385   project_241     26.134406     44.059930       20            عنيزة
#
#                  city_name_en  region_id region_key   region_name_ar  \
# ...

# %%
df.dtypes
# Out:
# id                                     object
# location_lat                          float64
# location_lon                          float64
# city_id                                 int64
# city_name_ar                           object
# city_name_en                           object
# region_id                               int64
# region_key                             object
# region_name_ar                         object
# region_name_en                         object
# region_order_sequence                   int64
# availability                            int64
# available_units_count                   int64
# available_units_for_auctions_count      int64
# basement                                int64
# bookable                                int64
# city_order_sequence                     int64
# delegated_by_broker                     int64
# developer_name                         object
# driver_room                             int64
# ...

# %%
df.isnull()
# Out:
#         id  location_lat  location_lon  city_id  city_name_ar  city_name_en  \
# 0    False         False         False    False         False         False
# 1    False         False         False    False         False         False
# 2    False         False         False    False         False         False
# 3    False         False         False    False         False         False
# 4    False         False         False    False         False         False
# ..     ...           ...           ...      ...           ...           ...
# 381  False         False         False    False         False         False
# 382  False         False         False    False         False         False
# 383  False         False         False    False         False         False
# 384  False         False         False    False         False         False
# 385  False         False         False    False         False         False
#
# ...

# %%
missing_values = df. isnull().sum()
print (missing_values)
# Out:
# id                                      0
# location_lat                            0
# location_lon                            0
# city_id                                 0
# city_name_ar                            0
# city_name_en                            0
# region_id                               0
# region_key                              0
# region_name_ar                          0
# region_name_en                          0
# region_order_sequence                   0
# availability                            0
# available_units_count                   0
# available_units_for_auctions_count      0
# basement                                0
# bookable                                0
# city_order_sequence                     0
# delegated_by_broker                     0
# developer_name                        213
# driver_room                             0
# elevator                                0
# group_unit_id                           0
# ...

# %%
df. drop(['views_count','location_lat', 'id', 'city_order_sequence', 'available_units_for_auctions_count', 'region_order_sequence'], axis=1, inplace=True)

# %%
duplicate_rows = df.duplicated()
print(df[duplicate_rows])
# Out:
# Empty DataFrame
# Columns: [location_lon, city_id, city_name_ar, city_name_en, region_id, region_key, region_name_ar, region_name_en, availability, available_units_count, basement, bookable, delegated_by_broker, developer_name, driver_room, elevator, group_unit_id, maid_room, max_area, max_bathroom, max_bed_room, max_price, max_street_width, max_unit_age, min_area, min_bathroom, min_bed_room, min_price, min_street_width, min_unit_age, pool, project_name, project_type, promoted, publish, publish_date, resource_id, resource_type, subsidizable, type, under_construction_status, unit_types_0, unit_types_1, unit_types_2, use_register_interest_flag]
# Index: []
#
# [0 rows x 45 columns]

# %%
df.head()
# Out:
#    location_lon  city_id city_name_ar city_name_en  region_id region_key  \
# 0     46.519438       14       الرياض    AR RIYADH          1     riyadh
# 1     46.633768       14       الرياض    AR RIYADH          1     riyadh
# 2     42.836919     3025         عفيف         AFIF          1     riyadh
# 3     42.098271     3274        محايل      MUHAYIL          7       asir
# 4     44.404584      716     الدوادمي  AD DUWADIMI          1     riyadh
#
#   region_name_ar region_name_en  availability  available_units_count  ...  \
# 0         الرياض         Riyadh             1                     14  ...
# 1         الرياض         Riyadh             1                      0  ...
# 2         الرياض         Riyadh             1                     61  ...
# 3           عسير          'Asir             0                      0  ...
# 4         الرياض         Riyadh             0                      0  ...
#
#    publish_date  resource_id  resource_type subsidizable          type  \
# ...

# %%
df.tail()
# Out:
#      location_lon  city_id     city_name_ar              city_name_en  \
# 381     43.612227       24         البكيرية             AL BUKAYRIYAH
# 382     43.152436     2798       سراة عبيدة              SARAT ABIDAH
# 383     39.807306       26  المدينة المنورة  AL MADINAH AL MUNAWWARAH
# 384     42.519739       50             ابها                      ABHA
# 385     44.059930       20            عنيزة                   UNAYZAH
#
#      region_id region_key   region_name_ar region_name_en  availability  \
# 381          5     qassim           القصيم         Qassim             0
# 382          7       asir             عسير          'Asir             0
# 383          3    madinah  المدينة المنورة        Madinah             1
# 384          7       asir             عسير          'Asir             0
# 385          5     qassim           القصيم         Qassim             0
#
#      available_units_count  ...  publish_date  resource_id  resource_type  \
# ...

# %%
# استيراد المكتبة المطلوبة
import pandas as pd

# افتح ملف البيانات أو قم بتحميله من قاعدة البيانات
# يفترض هنا أن 'df' هو الإطار البيانات الذي يحتوي على البيانات

# حساب الإحصائيات الوصفية للمتغيرات الرقمية
summary_statistics = df.describe()

# طباعة الإحصائيات الوصفية
print(summary_statistics)
# Out:
#        location_lon      city_id   region_id  availability  \
# count    386.000000   386.000000  386.000000    386.000000
# mean      41.244821  1086.958549    4.202073      0.401554
# std       10.795016  1280.105646    3.260244      0.490849
# min        0.000000     0.000000    1.000000      0.000000
# 25%       39.902613    31.000000    1.000000      0.000000
# 50%       42.850466    57.000000    4.000000      0.000000
# 75%       46.624452  2398.750000    6.000000      1.000000
# max       50.226499  3768.000000   13.000000      1.000000
#
#        available_units_count  basement    bookable  delegated_by_broker  \
# count             386.000000     386.0  386.000000                386.0
# mean               32.930052       0.0    0.818653                  0.0
# std                97.711916       0.0    0.385806                  0.0
# min                 0.000000       0.0    0.000000                  0.0
# ...

# %%
print(df['location_lon'].value_counts())
# Out:
# location_lon
# 0.000000     22
# 49.988667     2
# 38.013819     2
# 39.097564     2
# 36.516250     2
#              ..
# 38.374053     1
# 42.693603     1
# 44.180284     1
# 42.920256     1
# 44.059930     1
# Name: count, Length: 361, dtype: int64

# %%
region_ids = df['region_id'].unique()
print(region_ids)
# Out:
# [ 1  7  5 12  2  8  6  3 11 13  4 10  9]

# %%
print(df.describe())
# Out:
#        location_lon      city_id   region_id  availability  \
# count    386.000000   386.000000  386.000000    386.000000
# mean      41.244821  1086.958549    4.202073      0.401554
# std       10.795016  1280.105646    3.260244      0.490849
# min        0.000000     0.000000    1.000000      0.000000
# 25%       39.902613    31.000000    1.000000      0.000000
# 50%       42.850466    57.000000    4.000000      0.000000
# 75%       46.624452  2398.750000    6.000000      1.000000
# max       50.226499  3768.000000   13.000000      1.000000
#
#        available_units_count  basement    bookable  delegated_by_broker  \
# count             386.000000     386.0  386.000000                386.0
# mean               32.930052       0.0    0.818653                  0.0
# std                97.711916       0.0    0.385806                  0.0
# min                 0.000000       0.0    0.000000                  0.0
# ...

# %%
print(df.shape)
# Out:
# (386, 45)

# %%
print(df['publish'].value_counts())
# Out:
# publish
# 1    386
# Name: count, dtype: int64

# %%
missing_values = df.isna().sum()
print(missing_values)
# Out:
# location_lon                    0
# city_id                         0
# city_name_ar                    0
# city_name_en                    0
# region_id                       0
# region_key                      0
# region_name_ar                  0
# region_name_en                  0
# availability                    0
# available_units_count           0
# basement                        0
# bookable                        0
# delegated_by_broker             0
# developer_name                213
# driver_room                     0
# elevator                        0
# group_unit_id                   0
# maid_room                       0
# max_area                        0
# max_bathroom                    0
# max_bed_room                    0
# max_price                       0
# max_street_width                0
# max_unit_age                    0
# min_area                        0
# min_bathroom                    0
# min_bed_room                    0
# ...

# %%
default_value = 0
df['unit_types_1'] = default_value

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   location_lon                386 non-null    float64
#  1   city_id                     386 non-null    int64
#  2   city_name_ar                386 non-null    object
#  3   city_name_en                386 non-null    object
#  4   region_id                   386 non-null    int64
#  5   region_key                  386 non-null    object
#  6   region_name_ar              386 non-null    object
#  7   region_name_en              386 non-null    object
#  8   availability                386 non-null    int64
#  9   available_units_count       386 non-null    int64
#  10  basement                    386 non-null    int64
#  11  bookable                    386 non-null    int64
#  12  delegated_by_broker         386 non-null    int64
# ...

# %%
import pandas as pd

# قراءة البيانات من الملف
data = pd.read_csv(r"C:\Users\Ahliy\Downloads\Sakani Projects.csv")

# تحديد المنطقة المعينة
target_area = "AR RIYADH"

# حساب متوسط الإفراج للسكن في المنطقة المعينة
average_release = data[data['city_name_en'] == target_area]['city_id'].mean()

print("متوسط الإفراج للسكن في المنطقة الرياض:", average_release)
# Out:
# متوسط الإفراج للسكن في المنطقة الرياض: 14.0

# %%
data
# Out:
#                id  location_lat  location_lon  city_id     city_name_ar  \
# 0    project_1044     24.560109     46.519438       14           الرياض
# 1    project_1033     24.793165     46.633768       14           الرياض
# 2     project_681     24.058337     42.836919     3025             عفيف
# 3     project_378     18.446355     42.098271     3274            محايل
# 4     project_386     24.545443     44.404584      716         الدوادمي
# ..            ...           ...           ...      ...              ...
# 381   project_238     26.177791     43.612227       24         البكيرية
# 382   project_236     18.025902     43.152436     2798       سراة عبيدة
# 383   project_237     24.469556     39.807306       26  المدينة المنورة
# 384   project_374     18.343258     42.519739       50             ابها
# 385   project_241     26.134406     44.059930       20            عنيزة
#
#                  city_name_en  region_id region_key   region_name_ar  \
# ...
